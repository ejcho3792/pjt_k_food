# %%
from tensorflow.keras.models import load_model


model = load_model('./logs/n_.h5')
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               6422784
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_11 (Dense)             (None, 149)               38293
# =================================================================
# Total params: 21,176,789
# Trainable params: 13,541,013
# Non-trainable params: 7,635,776
# _________________________________________________________________

# %%
import json
with open("classes.txt", "r") as fp:
    classes = json.load(fp)

# %%
from PIL import Image
import numpy as np
# %matplotlib inline

tst_img_rt='./Img_002_0024.jpg'
tst = Image.open(tst_img_rt)
display(tst)
tst=tst.resize((224,224))
tst=np.expand_dims(tst,axis=0)
prd=model.predict(tst)
prd=np.argmax(prd[0])

print('예측 : ',classes[prd])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=532x400 at 0x1FC797813C8>
# 예측 :  고등어구이

# %%
####
import json
import numpy as np
from PIL import Image
from tensorflow.keras.models import load_model

def prd_img(img_dir):
    model = load_model('./logs/n_.h5')
    with open("classes.txt", "r") as fp:
        classes = json.load(fp)
    tst = Image.open(img_dir)
    tst=tst.resize((224,224))
    tst=np.expand_dims(tst,axis=0)
    prd=model.predict(tst)
    prd=np.argmax(prd[0])
    return classes[prd]

img_dir='./Img_002_0024.jpg'
prd_img(img_dir)
# Out:
# '고등어구이'
